# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = -1000
b = 1000

y, x = np.ogrid[-500:500:1000j, -500:500:1000j]
plt.contour(x.ravel(), y.ravel(), pow(y, 2) - pow(x, 3) - x * a - b, [0])
plt.grid()
plt.show()
